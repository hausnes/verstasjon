# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/hausnes/verstasjon/main/data/hausnes-verstasjon-inne-varmepumpe.csv')
df.head()
# Out:
#                   created_at  entry_id  temperatur        trykk  fuktighet  \
# 0  2022-01-23T17:44:15+01:00         1   30.563932  1018.108912  22.357349
# 1  2022-01-23T17:47:40+01:00         2   27.876904  1018.305328  25.822659
# 2  2022-01-23T17:48:14+01:00         3   27.756700  1018.367100  26.009871
# 3  2022-01-23T17:49:13+01:00         4   27.473793  1018.355360  26.435204
# 4  2022-01-23T17:50:13+01:00         5   27.289207  1018.368375  26.723868
#
#         lys  pm1  pm25  pm10  latitude  longitude  elevation  status
# 0  14.01635  0.0   1.0   1.0       NaN        NaN        NaN     NaN
# 1  75.02205  0.0   1.0   0.0       NaN        NaN        NaN     NaN
# 2  75.02205  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 3  71.90540  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 4  71.90540  0.0   0.0   0.0       NaN        NaN        NaN     NaN

# %%
df.tail()
# Out:
#                       created_at  entry_id  temperatur       trykk  fuktighet  \
# 42451  2022-02-22T08:44:13+01:00     42452   27.742110  995.787094  17.341236
# 42452  2022-02-22T08:45:13+01:00     42453   27.759554  995.776359  17.323651
# 42453  2022-02-22T08:46:13+01:00     42454   27.748771  995.766268  17.318598
# 42454  2022-02-22T08:47:13+01:00     42455   27.792856  995.769800  17.288553
# 42455  2022-02-22T08:48:13+01:00     42456   27.851531  995.745865  17.268948
#
#             lys  pm1  pm25  pm10  latitude  longitude  elevation  status
# 42451  24.02995  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42452  24.02995  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42453  24.02995  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42454  26.16920  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42455  26.16920  0.0   0.0   0.0       NaN        NaN        NaN     NaN

# %%
df.dtypes
# Out:
# created_at     object
# entry_id        int64
# temperatur    float64
# trykk         float64
# fuktighet     float64
# lys           float64
# pm1           float64
# pm25          float64
# pm10          float64
# latitude      float64
# longitude     float64
# elevation     float64
# status        float64
# dtype: object

# %%
df['created_at'] = pd.to_datetime(df['created_at'])

# %%
df.dtypes
# Out:
# created_at    datetime64[ns, pytz.FixedOffset(60)]
# entry_id                                     int64
# temperatur                                 float64
# trykk                                      float64
# fuktighet                                  float64
# lys                                        float64
# pm1                                        float64
# pm25                                       float64
# pm10                                       float64
# latitude                                   float64
# longitude                                  float64
# elevation                                  float64
# status                                     float64
# dtype: object

# %%
df['temperatur']
# Out:
# 0        30.563932
# 1        27.876904
# 2        27.756700
# 3        27.473793
# 4        27.289207
#            ...
# 42451    27.742110
# 42452    27.759554
# 42453    27.748771
# 42454    27.792856
# 42455    27.851531
# Name: temperatur, Length: 42456, dtype: float64

# %%
df['created_at']
# Out:
# 0       2022-01-23 17:44:15+01:00
# 1       2022-01-23 17:47:40+01:00
# 2       2022-01-23 17:48:14+01:00
# 3       2022-01-23 17:49:13+01:00
# 4       2022-01-23 17:50:13+01:00
#                    ...
# 42451   2022-02-22 08:44:13+01:00
# 42452   2022-02-22 08:45:13+01:00
# 42453   2022-02-22 08:46:13+01:00
# 42454   2022-02-22 08:47:13+01:00
# 42455   2022-02-22 08:48:13+01:00
# Name: created_at, Length: 42456, dtype: datetime64[ns, pytz.FixedOffset(60)]

# %%
df[df.temperatur > 30]
# Out:
#                  created_at  entry_id  temperatur        trykk  fuktighet  \
# 0 2022-01-23 17:44:15+01:00         1   30.563932  1018.108912  22.357349
#
#         lys  pm1  pm25  pm10  latitude  longitude  elevation  status
# 0  14.01635  0.0   1.0   1.0       NaN        NaN        NaN     NaN

# %%
df[df['created_at'].dt.strftime('%Y-%m-%d') == '2022-02-21'] 
# https://strftime.org/
# Out:
#                      created_at  entry_id  temperatur       trykk  fuktighet  \
# 40493 2022-02-21 00:00:13+01:00     40494   28.149345  966.075576  19.196908
# 40494 2022-02-21 00:01:13+01:00     40495   28.133804  966.062195  19.214342
# 40495 2022-02-21 00:02:13+01:00     40496   28.086864  966.038986  19.249914
# 40496 2022-02-21 00:03:13+01:00     40497   28.119532  965.995011  19.198239
# 40497 2022-02-21 00:04:12+01:00     40498   28.103357  965.999822  19.204541
# ...                         ...       ...         ...         ...        ...
# 41928 2022-02-21 23:55:13+01:00     41929   27.298721  998.547243  19.886362
# 41929 2022-02-21 23:56:13+01:00     41930   27.306016  998.537926  19.785808
# 41930 2022-02-21 23:57:13+01:00     41931   27.318068  998.565763  19.796427
# 41931 2022-02-21 23:58:13+01:00     41932   27.301259  998.598286  19.869547
# 41932 2022-02-21 23:59:13+01:00     41933   27.339318  998.597752  19.773234
#
#        lys  pm1  pm25  pm10  latitude  longitude  elevation  status
# 40493  0.0  8.0  10.0  10.0       NaN        NaN        NaN     NaN
# 40494  0.0  7.0  11.0   9.0       NaN        NaN        NaN     NaN
# 40495  0.0  7.0  13.0  14.0       NaN        NaN        NaN     NaN
# 40496  0.0  7.0   8.0   8.0       NaN        NaN        NaN     NaN
# 40497  0.0  6.0   8.0   7.0       NaN        NaN        NaN     NaN
# ...    ...  ...   ...   ...       ...        ...        ...     ...
# 41928  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41929  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41930  0.0  0.0   1.0   1.0       NaN        NaN        NaN     NaN
# 41931  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41932  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
#
# [1440 rows x 13 columns]

# %%
df[df['created_at'].dt.strftime('%Y-%m-%d') == '2022-02-21']
# Out:
#                      created_at  entry_id  temperatur       trykk  fuktighet  \
# 40493 2022-02-21 00:00:13+01:00     40494   28.149345  966.075576  19.196908
# 40494 2022-02-21 00:01:13+01:00     40495   28.133804  966.062195  19.214342
# 40495 2022-02-21 00:02:13+01:00     40496   28.086864  966.038986  19.249914
# 40496 2022-02-21 00:03:13+01:00     40497   28.119532  965.995011  19.198239
# 40497 2022-02-21 00:04:12+01:00     40498   28.103357  965.999822  19.204541
# ...                         ...       ...         ...         ...        ...
# 41928 2022-02-21 23:55:13+01:00     41929   27.298721  998.547243  19.886362
# 41929 2022-02-21 23:56:13+01:00     41930   27.306016  998.537926  19.785808
# 41930 2022-02-21 23:57:13+01:00     41931   27.318068  998.565763  19.796427
# 41931 2022-02-21 23:58:13+01:00     41932   27.301259  998.598286  19.869547
# 41932 2022-02-21 23:59:13+01:00     41933   27.339318  998.597752  19.773234
#
#        lys  pm1  pm25  pm10  latitude  longitude  elevation  status
# 40493  0.0  8.0  10.0  10.0       NaN        NaN        NaN     NaN
# 40494  0.0  7.0  11.0   9.0       NaN        NaN        NaN     NaN
# 40495  0.0  7.0  13.0  14.0       NaN        NaN        NaN     NaN
# 40496  0.0  7.0   8.0   8.0       NaN        NaN        NaN     NaN
# 40497  0.0  6.0   8.0   7.0       NaN        NaN        NaN     NaN
# ...    ...  ...   ...   ...       ...        ...        ...     ...
# 41928  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41929  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41930  0.0  0.0   1.0   1.0       NaN        NaN        NaN     NaN
# 41931  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41932  0.0  0.0   0.0   0.0       NaN        NaN        NaN     NaN
#
# [1440 rows x 13 columns]

# %%
import matplotlib.pyplot as plt
df[df['created_at'].dt.strftime('%Y-%m-%d') == '2022-02-21'].pm1.plot(label="pm1")
#df[df['created_at'].dt.strftime('%Y-%m-%d') == '2022-02-21'].pm25.plot(label="pm2.5")
#df[df['created_at'].dt.strftime('%Y-%m-%d') == '2022-02-21'].pm10.plot(label="pm10")
plt.legend()
plt.show()

# %%
df[df['created_at'].dt.strftime('%Y-%m-%d %H:%M:%S') == '2022-02-21 15:00:12']
# Out:
#                      created_at  entry_id  temperatur       trykk  fuktighet  \
# 41393 2022-02-21 15:00:12+01:00     41394   28.284139  983.686043  18.381384
#
#             lys  pm1  pm25  pm10  latitude  longitude  elevation  status
# 41393  25.87445  0.0   0.0   0.0       NaN        NaN        NaN     NaN

# %%
df[df['created_at'].dt.strftime('%Y-%m-%d %H:%M:%S') > '2022-02-21 15:00:00']
# Out:
#                      created_at  entry_id  temperatur       trykk  fuktighet  \
# 41393 2022-02-21 15:00:12+01:00     41394   28.284139  983.686043  18.381384
# 41394 2022-02-21 15:01:13+01:00     41395   28.236248  983.747222  18.428273
# 41395 2022-02-21 15:02:13+01:00     41396   28.241005  983.726760  18.422470
# 41396 2022-02-21 15:03:14+01:00     41397   28.221341  983.765775  18.440130
# 41397 2022-02-21 15:04:13+01:00     41398   28.283505  983.733867  18.386997
# ...                         ...       ...         ...         ...        ...
# 42451 2022-02-22 08:44:13+01:00     42452   27.742110  995.787094  17.341236
# 42452 2022-02-22 08:45:13+01:00     42453   27.759554  995.776359  17.323651
# 42453 2022-02-22 08:46:13+01:00     42454   27.748771  995.766268  17.318598
# 42454 2022-02-22 08:47:13+01:00     42455   27.792856  995.769800  17.288553
# 42455 2022-02-22 08:48:13+01:00     42456   27.851531  995.745865  17.268948
#
#             lys  pm1  pm25  pm10  latitude  longitude  elevation  status
# 41393  25.87445  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41394  24.52815  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41395  28.99110  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41396  52.98490  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 41397  49.13045  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# ...         ...  ...   ...   ...       ...        ...        ...     ...
# 42451  24.02995  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42452  24.02995  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42453  24.02995  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42454  26.16920  0.0   0.0   0.0       NaN        NaN        NaN     NaN
# 42455  26.16920  0.0   0.0   0.0       NaN        NaN        NaN     NaN
#
# [1063 rows x 13 columns]

# %%
df[df['created_at'].dt.strftime('%Y-%m-%d %H:%M:%S') > '2022-02-21 15:00:00']
and df['created_at'].dt.strftime('%Y-%m-%d %H:%M:%S') < '2022-02-21 16:00:00'
